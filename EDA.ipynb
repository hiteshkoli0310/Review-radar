# %%
import subprocess
import sys

subprocess.check_call([sys.executable, "-m", "ensurepip"])
subprocess.check_call([sys.executable, "-m", "pip", "install", "pandas", "pyarrow"])
# Out:
# 0

# %%
import sys
# !{sys.executable} -m ensurepip
# Out:
# Looking in links: c:\Users\venom\AppData\Local\Temp\tmp45rtpgy1
# Requirement already satisfied: pip in c:\Users\venom\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (26.1.1)

# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\Users\venom\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in c:\Users\venom\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\venom\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\venom\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\venom\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in c:\Users\venom\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (24.0.0)
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pathlib import Path
import pandas as pd

data_root = Path.cwd() / "data" / "raw"
videos_path = data_root / "videos" / "iphone_17_videos.parquet"
comments_path = data_root / "comments" / "iphone_17_comments.parquet"

videos = pd.read_parquet(
    videos_path
)

comments = pd.read_parquet(
    comments_path
)

print("Videos:", videos.shape)
print("Comments:", comments.shape)
# Out:
# Videos: (10, 12)
# Comments: (764, 10)

# %%
print(videos.columns.tolist())
print(comments.columns.tolist())
# Out:
# ['video_id', 'product_query', 'title', 'video_url', 'channel_name', 'published_at', 'view_count', 'like_count', 'comment_count', 'duration', 'tags', 'category_id']
# ['product_query', 'video_id', 'video_url', 'video_title', 'comment_id', 'author_name', 'comment_text', 'like_count', 'published_at', 'updated_at']

# %%
comments[["comment_text"]].sample(10)
# Out:
#                                           comment_text
# 268  Bro I have a iphone 15Pm and is switching to i...
# 94   Bro just active iphone okke safe ahno? 10k dif...
# 696  Just went from Iphone 14 pro to Iphone 17!!!! ...
# 753    Me iqoo se khush hu humko nhi chahiye iphone😂😂😂
# 196                             Link to wallpaper plz!
# 12   5G ഇട്ടിട്ട് HOTSPOT ഇട്ടിട്ട് video എടുത്താ b...
# 7      ആപ്പിൾ ഫോണിൻ്റെ എത്ര വോൾട്ട് ചാർജർ ആണ് എടുക്കുക
# 695                                        Gooood job!
# 91   Nxt amazon flip big billion days sale date ari...
# 755  Bro iPhone 17 ka freedom sale me price Kya hog...
